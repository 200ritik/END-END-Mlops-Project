# %%
# this note book generally design for to push he data in the mongo db
import pandas as pd
import pymongo
df = pd.read_csv("data.csv")  # Assuming you have a CSV file named 'data.csv'

# %%
#  df should be in the dict before pushing it

data = df.to_dict(orient='records')  # Convert DataFrame to a list of dictionaries

# %%
# data

# %%
DB_NAME = "Proj1"

COLLECTION_NAME = "Proj1_Data"
CONNECTION_URL = "mongodb+srv://ritik:Ritik2026MongoDB@cluster0.rhpoom2.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"# remove the id pass or hide it before commit
# mongodb+srv://ritiksharma7141_db_user:D2.pJ2n_hVH3rz@cluster0.rhpoom2.mongodb.net/?appName=Cluster0

# %%
client = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DB_NAME]  
collection = data_base[COLLECTION_NAME]

# %%
# uploading data to mongo db

rec=collection.insert_many(data)

# %%
from pymongo import MongoClient

uri = "mongodb+srv://ritik:Ritik2026MongoDB@cluster0.rhpoom2.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"
client = MongoClient(uri)

print(client.admin.command("ping"))
# Out:
# {'ok': 1}
